# %% [markdown]
# # **Simulation Hedy 2024**

# %% [markdown]
# Team: TU Wien Space Team \
# Project: Lamarr \
# Rocket: Hedy \

# %% [markdown]
# ## Installs

# %% [markdown]
# In this section all needed libraries are installed and the needed classes imported

# %%
# %pip install "netCDF4<1.6.0"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting netCDF4<1.6.0
#   Using cached netCDF4-1.5.8.tar.gz (767 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [27 lines of output]
#       reading from setup.cfg...
#       Package hdf5 was not found in the pkg-config search path.
#       Perhaps you should add the directory containing `hdf5.pc'
#       to the PKG_CONFIG_PATH environment variable
#       Package 'hdf5' not found
#
#           HDF5_DIR environment variable not set, checking some standard locations ..
#       checking /home/diego/include ...
#       hdf5 headers not found in /home/diego/include
#       checking /usr/local/include ...
#       hdf5 headers not found in /usr/local/include
#       checking /sw/include ...
#       hdf5 headers not found in /sw/include
#       checking /opt/include ...
#       hdf5 headers not found in /opt/include
#       checking /opt/local/include ...
#       hdf5 headers not found in /opt/local/include
#       checking /usr/include ...
#       hdf5 headers not found in /usr/include
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-k9oixf65/netcdf4_0f4cb725b22c491bb6df46273b889ee3/setup.py", line 419, in <module>
#           _populate_hdf5_info(dirstosearch, inc_dirs, libs, lib_dirs)
#         File "/tmp/pip-install-k9oixf65/netcdf4_0f4cb725b22c491bb6df46273b889ee3/setup.py", line 360, in _populate_hdf5_info
#           raise ValueError('did not find HDF5 headers')
#       ValueError: did not find HDF5 headers
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install rocketpy==1.8.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rocketpy==1.8.0 in /var/data/python/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.13 in /var/data/python/lib/python3.12/site-packages (from rocketpy==1.8.0) (2.2.3)
# Requirement already satisfied: scipy>=1.0 in /var/data/python/lib/python3.12/site-packages (from rocketpy==1.8.0) (1.15.2)
# Requirement already satisfied: matplotlib>=3.0 in /var/data/python/lib/python3.12/site-packages (from rocketpy==1.8.0) (3.10.1)
# Requirement already satisfied: netCDF4>=1.6.4 in /var/data/python/lib/python3.12/site-packages (from rocketpy==1.8.0) (1.7.2)
# Requirement already satisfied: requests in /var/data/python/lib/python3.12/site-packages (from rocketpy==1.8.0) (2.32.3)
# Requirement already satisfied: pytz in /var/data/python/lib/python3.12/site-packages (from rocketpy==1.8.0) (2025.1)
# Requirement already satisfied: simplekml in /var/data/python/lib/python3.12/site-packages (from rocketpy==1.8.0) (1.3.6)
# Requirement already satisfied: dill in /var/data/python/lib/python3.12/site-packages (from rocketpy==1.8.0) (0.3.9)
# Requirement already satisfied: contourpy>=1.0.1 in /var/data/python/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy==1.8.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /var/data/python/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy==1.8.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /var/data/python/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy==1.8.0) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /var/data/python/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy==1.8.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy==1.8.0) (24.2)
# Requirement already satisfied: pillow>=8 in /var/data/python/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy==1.8.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /var/data/python/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy==1.8.0) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /var/data/python/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy==1.8.0) (2.9.0.post0)
# Requirement already satisfied: cftime in /var/data/python/lib/python3.12/site-packages (from netCDF4>=1.6.4->rocketpy==1.8.0) (1.6.4.post1)
# Requirement already satisfied: certifi in /var/data/python/lib/python3.12/site-packages (from netCDF4>=1.6.4->rocketpy==1.8.0) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in /var/data/python/lib/python3.12/site-packages (from requests->rocketpy==1.8.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /var/data/python/lib/python3.12/site-packages (from requests->rocketpy==1.8.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /var/data/python/lib/python3.12/site-packages (from requests->rocketpy==1.8.0) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->rocketpy==1.8.0) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install CoolProp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: CoolProp in /var/data/python/lib/python3.12/site-packages (6.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from rocketpy import Environment, SolidMotor, Rocket, Flight, Fluid, LiquidMotor, CylindricalTank, MassFlowRateBasedTank, TrapezoidalFins, FreeFormFins, EllipticalFins, RailButtons, NoseCone, Tail, Parachute
from math import exp
from math import pi
import datetime
import CoolProp.CoolProp as CP
from CoolProp.CoolProp import PropsSI
from rocketpy.mathutils import Function

# %% [markdown]
# ## Configuration

# %% [markdown]
# The length unit chosen here is millimeters to keep the values more readable. If necessary, values should be converted accordingly.

# %%
# Rocket configuration data
env_config = {
    "date" : (2025, 5, 10, 13, 00, 00),   # yyyy, mm, dd, hh, mm, ss    # preset to april date, because forecast only has one month of data
    "latitude" : 39.12368,                # Launch latitude             # preset
    "longitude" : -8.03333,               # Launch longitude            # preset
    "timezone" : "Europe/Lisbon"          # GMT+1                       # preset
}
motor_config = {
    "burn_time" : 5.1,                    # s       # preset  #is ignored in certain scenarios
    "holddown_time" : 1.5,                # s       # preset

    "nitrogen_tank" : {
        "length" : 235.411,               # mm      # measured
        "CG_lox" : 2622.95,               # mm      # measured #CD lox nitrogen tank
        "CG_ethanol" : 1422.1595,         # mm      # measured #CD ethanol nitrogen tank
        "outer_diameter": 93,             # mm      # measured
        "thickness" : 2,                  # mm      # measured
        "massflow" : 0.03,                # kg/s    # Estimate
    },
    "ethanol_tank" : {
        "length" : 573.61485,             # mm      # measured
        "CG" : 825.55,                    # mm      # measured
        "outer_diameter": 115,            # mm      # measured
        "thickness" : 2.5,                # mm      # measured
        "massflow" : 0.40,                # kg/s    # tested
    },
    "lox_tank" : {
        "length" : 573.978,               # mm      # measured
        "CG" : 1932.5205,                 # mm      # measured
        "outer_diameter" : 115,           # mm      # measured
        "thickness" : 2.5,                # mm      # measured
        "massflow" : 0.60,                 # kg/s    # tested
    },
    "nozzle" : {
        "diameter" : 75,                  # mm      # measured
        "position" : -40,                 # mm      # measured
    },

    "thrust": 2000,                       # N       # measured
    "overfill_percentage" : 0.001,        # %       # preset

    "mass" : {
      "ethanol" : 2.7,                    # kg     # preset
      "lox" : 3.5,                        # kg     # preset
    },
    "temperature" : {
        "ethanol" : 298.15,               # K       # preset (= 25°C)
        "lox" : 93.15,                    # K       # preset (= -180°C)
        "nitrogen" : 298.15               # K       # preset (= 25°C)
    },
    "pressure" : {
        "ethanol" : 3000000,              # Pa     # preset
        "lox" : 3000000,                  # Pa     # preset
        "nitrogen" : 30000000             # Pa     # preset
    }
}

rocket_config = {
    "total_weight" : 16200,               # g       # weighed
    "total_length" : 3745,                # mm      # measured
    "total_CG" : 1813,                    # mm      # measured
    "moment_of_intertia_Z" : 0.0255,      # kg*m^2  # calculated
    "moment_of_intertia_XY" : 16.8,       # kg*m^2  # calculated
    "nosecone" : {
        "length" : 630,                   # mm      # measured
        "kind" : "lv haack"
    },
    "railbuttons" : {
        "upper" : 1646.67,                # mm      # measured
        "lower" : 297.5,                  # mm      # measured
    },
    "tailcone" : {
        "diameter" : 97.8,                # mm      # measured
        "length" : 245.643,               # mm      # measured
        "cylindrical_height" : 34.8,      # mm      # measured
    },
    "rocket" : {
        "thickness" : 1.4,                # mm      # measured
        "diameter" : 132.8,               # mm      # measured
    },
    "fins" : {
        "name" : "Biconvex",
        "amount" : 4,
        "root_chord" : 199.0211,          # mm      # measured
        "tip_chord" : 79.4,               # mm      # measured
        "span" : 96.4,                    # mm      # measured
        "sweep_length" : 63.892,          # mm      # measured
        "position" : 233,                 # mm      # measured
        "shape_points" : ((0,0),
                          (-0.0265,0.0036),
                          (-0.0902,0.114),
                          (-0.170,0.114),
                          (-0.234,0.017),
                          (-0.0265,0.00359),
                          (0,0))                # m     # measured
    },
    "parachutes" : {
        "main" : {
            "cd_s" : 6.911503837897546,                     # calculated
            "trigger" : 450,              # m               # preset
            "sampling_rate" : 105,        # hz              # preset
            "lag" : 4,                    # s               # measured
            "noise" : (0, 8.3, 0.5)       # (pa, pa, pa)    # preset
        },
        "drogue" : {
            "cd_s" : 0.336875,
            "trigger" : "apogee",         # m               # preset
            "sampling_rate" : 105,        # hz              # preset
            "lag" : 1,                    # s               # measured
            "noise" : (0, 8.3, 0.5)       # (pa, pa, pa)    # preset
        }
    }
}
flight_config = {
    "rail_length" : 11,                   # m       #Preset
    "inclination" : 84,                   # °       #Preset
    "heading" : 133,                      # °       #Preset
    "terminate_on_apogee" : False,
}

# %% [markdown]
# ## Environments Initialization

# %% [markdown]
# In this Section the environments are initialized.
# *   **envForecast**: environment with the weather data from the wyoming-sounding data source at the location and date of EuRoc
# *   **envNormal**: normalized environment with standard atmospheric values at the time and location of EuRoc
# *   **envCostom**: custom environment with variable values for temperature and windspeed

# %%
#Ponte de Sor: 39.12368, -8.03333
#EUROC: 09.-15.10.2025
#possible launch date: 11.10.2025


latitude   = env_config["latitude"]
longitude  = env_config["longitude"]
timezone   = env_config["timezone"]
date       = env_config["date"]

#Environment based on Forecast data for the EuRoC 2025
envForecast = Environment()

envForecast.set_location(latitude = latitude, longitude = longitude)
envForecast.set_elevation("Open-Elevation")
envForecast.set_date(date, timezone = timezone)

envForecast.set_atmospheric_model(type="Forecast", file="GFS")
envForecast.info()


#Environment based on standard values
envNormal = Environment()
envNormal.set_location(latitude = latitude, longitude = longitude)
envNormal.set_elevation("Open-Elevation")
envNormal.set_date(date, timezone = timezone)
envNormal.set_atmospheric_model(type = "standard_atmosphere")
envNormal.info()

#Environment based on Custom Data
envCustom = Environment()
envCustom.set_location(latitude = latitude, longitude = longitude)
envCustom.set_atmospheric_model(type = "custom_atmosphere", temperature = 30 + 273.15, wind_u = lambda t:10 + (t /1000)**2, wind_v = 0)
envCustom.info()
# Out:
# Fetching elevation from open-elevation.com for lat=39.12368, lon=-8.03333...
# Elevation received: 161.0 m
#
# Gravity Details
#
# Acceleration of gravity at surface level:    9.7798 m/s²
# Acceleration of gravity at  80.343 km (ASL): 9.5379 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2025-05-10 12:00:00 UTC | 2025-05-10 13:00:00 Europe/Lisbon
# Launch Site Latitude: 39.12368°
# Launch Site Longitude: -8.03333°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 166021.44 W|E    0.00 N
# Launch Site UTM zone: 31N
# Launch Site Surface Elevation: 158.0 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: Forecast
# Forecast Maximum Height: 80.343 km
# Forecast Time Period: from 2025-04-29 12:00:00 to 2025-05-15 12:00:00 utc
# Forecast Hour Interval: 3 hrs
# Forecast Latitude Range: From -90.0° to 90.0°
# Forecast Longitude Range: From 0.0° to 359.75°
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 2.89 m/s
# Surface Wind Direction: 301.81°
# Surface Wind Heading: 121.81°
# Surface Pressure: 997.53 hPa
# Surface Temperature: 295.07 K
# Surface Air Density: 1.178 kg/m³
# Surface Speed of Sound: 344.36 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6378.14 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
# Atmospheric Model Plots
# Fetching elevation from open-elevation.com for lat=39.12368, lon=-8.03333...
# Elevation received: 161.0 m
#
# Gravity Details
#
# Acceleration of gravity at surface level:    9.7798 m/s²
# Acceleration of gravity at  80.000 km (ASL): 9.5379 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2025-05-10 12:00:00 UTC | 2025-05-10 13:00:00 Europe/Lisbon
# Launch Site Latitude: 39.12368°
# Launch Site Longitude: -8.03333°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 166021.44 W|E    0.00 N
# Launch Site UTM zone: 31N
# Launch Site Surface Elevation: 161.0 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: standard_atmosphere
# standard_atmosphere Maximum Height: 80.000 km
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 0.00 m/s
# Surface Wind Direction: 0.00°
# Surface Wind Heading: 0.00°
# Surface Pressure: 994.36 hPa
# Surface Temperature: 287.11 K
# Surface Air Density: 1.207 kg/m³
# Surface Speed of Sound: 339.63 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6378.14 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
# Atmospheric Model Plots
# Gravity Details
#
# Acceleration of gravity at surface level:    9.7803 m/s²
# Acceleration of gravity at  80.000 km (ASL): 9.5379 m/s²
#
#
# Launch Site Details
#
# Launch Site Latitude: 39.12368°
# Launch Site Longitude: -8.03333°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 166021.44 W|E    0.00 N
# Launch Site UTM zone: 31N
# Launch Site Surface Elevation: 0.0 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: custom_atmosphere
# custom_atmosphere Maximum Height: 80.000 km
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 10.00 m/s
# Surface Wind Direction: 270.00°
# Surface Wind Heading: 90.00°
# Surface Pressure: 1013.25 hPa
# Surface Temperature: 303.15 K
# Surface Air Density: 1.164 kg/m³
# Surface Speed of Sound: 349.04 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6378.14 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
# Atmospheric Model Plots

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Tanks / Engine

# %%
#Burn time
t_burn              = motor_config["burn_time"]
#holddown time
t_holddown          = motor_config["holddown_time"]


# tank height
h_nitrogen_tank     = motor_config["nitrogen_tank"]["length"]     / 1000
h_ethanol_tank      = motor_config["ethanol_tank"]["length"]      / 1000
h_lox_tank          = motor_config["lox_tank"]["length"]          / 1000
#OuterDiameter
OD_nitrogen_tank    = motor_config["nitrogen_tank"]["outer_diameter"]   / 1000
OD_ethanol_tank     = motor_config["ethanol_tank"]["outer_diameter"]    / 1000
OD_lox_tank         = motor_config["lox_tank"]["outer_diameter"]        / 1000
#Thickness
Th_nitrogen_tank    = motor_config["nitrogen_tank"]["thickness"]  / 1000
Th_ethanol_tank     = motor_config["ethanol_tank"]["thickness"]   / 1000
Th_lox_tank         = motor_config["lox_tank"]["thickness"]       / 1000
#massflows
mdot_nitrogen       = motor_config["nitrogen_tank"] ["massflow"]
mdot_ethanol        = motor_config["ethanol_tank"]["massflow"]
mdot_lox            = motor_config["lox_tank"]["massflow"]
#nozzle
nozzle_diameter     = motor_config["nozzle"]["diameter"]          / 1000
nozzle_position     = motor_config["nozzle"]["position"]          / 1000


#thrust
thrust                    = motor_config["thrust"]
#Overfill
overfill_percentage       = motor_config["overfill_percentage"]


#masses
m_ethanol_preset    = motor_config["mass"]["ethanol"]
m_lox_preset        = motor_config["mass"]["lox"]
# Temperature Lox & Ethanol
T_nitrogen          = motor_config["temperature"]["nitrogen"]
T_ethanol           = motor_config["temperature"]["ethanol"]
T_lox               = motor_config["temperature"]["lox"]
# pressure LOX & Ethanol
p_nitrogen          = motor_config["pressure"]["nitrogen"]
p_ethanol           = motor_config["pressure"]["ethanol"]
p_lox               = motor_config["pressure"]["lox"]









# inner diameter
ID_nitrogen_tank = OD_nitrogen_tank - (2* Th_nitrogen_tank)     # m
ID_ethanol_tank = OD_ethanol_tank - (2 * Th_ethanol_tank)       # m
ID_lox_tank = OD_lox_tank - (2 * Th_lox_tank)                   # m

# Propellants
# mass
m_nitrogen_calculated = mdot_nitrogen * (t_burn)                # kg
m_ethanol_calculated = mdot_ethanol * (t_burn)                  # kg
m_lox_calculated = mdot_lox * (t_burn)                          # kg

# define density
rho_nitrogen = CP.PropsSI("D","T",T_nitrogen,"P|gas",p_nitrogen,"N2")             # kg/m^3
rho_ethanol = CP.PropsSI("D", "T|liquid", T_ethanol, "P", p_ethanol, "ethanol")   # kg/m^3
rho_lox = CP.PropsSI("D", "T|liquid", T_lox, "P", p_lox, "oxygen")                # kg/m^3

# define fluids
nitrogen = Fluid(name = "N2", density = rho_nitrogen)
ethanol = Fluid(name = "ethanol", density = rho_ethanol)
lox = Fluid(name = "LOX", density = rho_lox)

# define tanks geometry
nitrogen_tank_shape = CylindricalTank(radius = ID_nitrogen_tank / 2, height = h_nitrogen_tank, spherical_caps = True)
ethanol_tank_shape = CylindricalTank(radius = ID_ethanol_tank / 2, height = h_ethanol_tank, spherical_caps = True)
lox_tank_shape = CylindricalTank(radius = ID_lox_tank / 2, height = h_lox_tank, spherical_caps = True)




v_nitrogen_tank = nitrogen_tank_shape.volume(h_nitrogen_tank/2)   # m³
v_ethanol_tank = ethanol_tank_shape.volume(h_ethanol_tank/2)      # m³
v_lox_tank = lox_tank_shape.volume(h_lox_tank/2)                  # m³

m_nitrogen = v_nitrogen_tank * rho_nitrogen                   # m
m_ethanol = v_ethanol_tank * rho_ethanol                      # m
m_lox = v_lox_tank * rho_lox                                  # m

t_burn_nitrogen = (m_nitrogen / mdot_nitrogen)-0.001          # s


t_burn_ethanol = (m_ethanol / mdot_ethanol)
t_burn_lox = (m_lox / mdot_lox)

if(t_burn_ethanol<t_burn_lox):
  t_burn = t_burn_ethanol
  print(f"using ethanol burn time. LOX burntime is {t_burn_lox}")
else:
  t_burn = t_burn_lox
  print(f"using lox burn time. Ethanol burntime is {t_burn_ethanol}")


#account for holddown
t_burn -= t_holddown

m_lox = mdot_lox * t_burn + 0.0001
m_ethanol = mdot_ethanol * t_burn + 0.0001
m_nitrogen = mdot_nitrogen * t_burn + 0.0001

if(t_burn_nitrogen<t_burn):
  print("WARNING: TOO LITTLE NITROGEN, UNKNOWN EFFECTS")


# define tanks
nitrogen_tank = MassFlowRateBasedTank(
    name = "nitrogen tank",
    geometry = nitrogen_tank_shape,
    flux_time = t_burn,                                 # s
    initial_liquid_mass = 0,                            # kg
    initial_gas_mass = m_nitrogen,                      # kg
    liquid_mass_flow_rate_in = 0,                       # kg/s
    liquid_mass_flow_rate_out = 0,                      # kg/s
    gas_mass_flow_rate_in = 0,                          # kg/s
    gas_mass_flow_rate_out = lambda t: mdot_nitrogen,   # ks/s
    liquid = Fluid(name = "liquid", density = 0.0001),  # ignore
    gas = nitrogen,
)
ethanol_tank = MassFlowRateBasedTank(
    name = "fuel tank",
    geometry = ethanol_tank_shape,
    flux_time = t_burn,                                 # s
    initial_liquid_mass = m_ethanol,                    # kg
    initial_gas_mass = 0,                               # kg
    liquid_mass_flow_rate_in = 0,                       # kg/s
    liquid_mass_flow_rate_out = lambda t: mdot_ethanol, # kg/s
    gas_mass_flow_rate_in = lambda t: mdot_nitrogen,    # kg/s
    gas_mass_flow_rate_out = 0,                         # kg/s
    liquid = ethanol,
    gas = nitrogen,
)

lox_tank = MassFlowRateBasedTank(
    name = "oxidizer tank",
    geometry = lox_tank_shape,
    flux_time = t_burn,                                 # s
    initial_liquid_mass = m_lox,                        # kg
    initial_gas_mass = 0,                               # kg
    liquid_mass_flow_rate_in = 0,                       # kg/s
    liquid_mass_flow_rate_out = lambda t: mdot_lox,     # kg/s
    gas_mass_flow_rate_in = lambda t: mdot_nitrogen,    # kg/s
    gas_mass_flow_rate_out = 0,                         # kg/s
    liquid = lox,
    gas = nitrogen,
)

skuld = LiquidMotor(
    dry_mass = 0.0001,                  # kg
    dry_inertia = (0,0,0),              # kg*m^2
    center_of_dry_mass_position = 0,    # m

    nozzle_radius = nozzle_diameter /2, # m
    nozzle_position = nozzle_position,  # m

    thrust_source = lambda t: thrust,   # N
    burn_time = t_burn,                 # s
    coordinate_system_orientation = "nozzle_to_combustion_chamber"
)

skuld.add_tank(tank = lox_tank, position =        motor_config["ethanol_tank"]["CG"]                /1000)
skuld.add_tank(tank = ethanol_tank, position =    motor_config["lox_tank"]["CG"]            /1000)
skuld.add_tank(tank = nitrogen_tank, position =   motor_config["nitrogen_tank"]["CG_lox"]       /1000)
skuld.add_tank(tank = nitrogen_tank, position =   motor_config["nitrogen_tank"]["CG_ethanol"]   /1000)

skuld.all_info()
# Out:
# Warning: Adding spherical caps to the tank will not modify the total height of the tank 0.235411 m. Its cylindrical portion height will be reduced to 0.146411 m.
# Warning: Adding spherical caps to the tank will not modify the total height of the tank 0.57361485 m. Its cylindrical portion height will be reduced to 0.46361485 m.
# Warning: Adding spherical caps to the tank will not modify the total height of the tank 0.573978 m. Its cylindrical portion height will be reduced to 0.463978 m.
# using lox burn time. Ethanol burntime is 10.04915178759502
# Nozzle Details
# Nozzle Radius: 0.0375 m
#
# Motor Details
# Total Burning Time: 8.142720460442291 s
# Total Propellant Mass: 8.632 kg
# Structural Mass Ratio: 0.000
# Average Propellant Exhaust Velocity: 2000.000 m/s
# Average Thrust: 2000.000 N
# Maximum Thrust: 2000.0 N at 0.0 s after ignition.
# Total Impulse: 16285.441 Ns

# %% [markdown]
# ### Rocket components

# %%
#rocket
rocket_length     = rocket_config["total_length"]         / 1000
rocket_diameter   = rocket_config["rocket"]["diameter"]   / 1000
rocket_thickness  = rocket_config["rocket"]["thickness"]  / 1000


nosecone_length = (rocket_config["nosecone"]["length"]-80)    / 1000   # -80 mm to adjust for cylindrical section
nosecone_kind = rocket_config["nosecone"]["kind"]

nose_cone = NoseCone(
    length = nosecone_length,
    base_radius = rocket_diameter/2,
    kind = nosecone_kind
)

tailcone_cylindrical    = rocket_config["tailcone"]["cylindrical_height"] / 1000
tailcone_length         = rocket_config["tailcone"]["length"]             / 1000
tailcone_bottom_radius  = rocket_config["tailcone"]["diameter"]        /2 / 1000

tail = Tail(
    top_radius = rocket_diameter /2,
    bottom_radius = tailcone_bottom_radius,
    length = tailcone_length,
    rocket_radius = rocket_diameter/2
)

fin_amount        = rocket_config["fins"]["amount"]
fin_name          = rocket_config["fins"]["name"]
fin_position      = rocket_config["fins"]["position"]     / 1000
fin_root_chord    = rocket_config["fins"]["root_chord"]   / 1000
fin_tip_chord     = rocket_config["fins"]["tip_chord"]    / 1000
fin_span          = rocket_config["fins"]["span"]         / 1000
fin_sweep_length  = rocket_config["fins"]["sweep_length"] / 1000
fin_shape_points  = rocket_config["fins"]["shape_points"]

trapezoidal_fin_set = TrapezoidalFins(
    n = fin_amount,
    root_chord = fin_root_chord,      # m
    tip_chord = fin_tip_chord,        # m
    span = fin_span,                  # m
    sweep_length = fin_sweep_length,  # m
    name = fin_name,
    rocket_radius = rocket_diameter/2 # m
  )
trapezoidal_fin_set.draw()

fin_set = FreeFormFins(
   n = fin_amount,
   shape_points = fin_shape_points,         # m
   rocket_radius=tailcone_bottom_radius,    # m
   name = "Freeform"
)
fin_set.draw()

parachutes = {}

parachutes[0] = Parachute(
    name = "main",
    cd_s = rocket_config["parachutes"]["main"]["cd_s"],
    trigger = rocket_config["parachutes"]["main"]["trigger"],             # m
    sampling_rate = rocket_config["parachutes"]["main"]["sampling_rate"], # hz
    lag = rocket_config["parachutes"]["main"]["lag"],                     # s
    noise = rocket_config["parachutes"]["main"]["noise"],                 # (pa, pa, pa)
)

parachutes[1] = Parachute(
    name = "drogue",
    cd_s = rocket_config["parachutes"]["drogue"]["cd_s"],
    trigger = rocket_config["parachutes"]["drogue"]["trigger"],             # m
    sampling_rate = rocket_config["parachutes"]["drogue"]["sampling_rate"], # hz
    lag = rocket_config["parachutes"]["drogue"]["lag"],                     # s
    noise = rocket_config["parachutes"]["drogue"]["noise"],                 # (pa, pa, pa)
)

# %% [markdown]
# ### Hedy

# %%
total_mass        = rocket_config["total_weight"] / 1000

#inertia
inertia_x_y   = rocket_config["moment_of_intertia_XY"]
inertia_z     = rocket_config["moment_of_intertia_Z"]

upper_railbutton_position = rocket_config["railbuttons"]["upper"]/1000
lower_railbutton_position = rocket_config["railbuttons"]["lower"]/1000

#CG
CG = rocket_config["total_CG"] / 1000

hedy = Rocket(
    radius = rocket_diameter /2,                      # m
    mass = total_mass,                                # m
    inertia = (inertia_x_y, inertia_x_y, inertia_z),  # kg * m^2
    power_off_drag = "../power_off_drag.csv",
    power_on_drag = "../power_on_drag.csv",
    center_of_mass_without_motor = CG,                # m
    coordinate_system_orientation = "tail_to_nose"
)


hedy.add_motor(skuld, position = 0)


hedy.set_rail_buttons(upper_button_position= upper_railbutton_position, lower_button_position=lower_railbutton_position)

hedy.add_surfaces(surfaces=[nose_cone, fin_set, tail], positions=[rocket_length, 0, tailcone_length])

hedy.parachutes = list(parachutes.values())

hedy.all_info()
# Out:
# Inertia Details
#
# Rocket Mass: 16.200 kg (without motor)
# Rocket Dry Mass: 16.200 kg (with unloaded motor)
# Rocket Loaded Mass: 24.832 kg
# Rocket Structural Mass Ratio: 0.652
# Rocket Inertia (with unloaded motor) 11: 16.800 kg*m2
# Rocket Inertia (with unloaded motor) 22: 16.800 kg*m2
# Rocket Inertia (with unloaded motor) 33: 0.025 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.0664 m
# Rocket Frontal Area: 0.013851 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.000 m
# Rocket Center of Dry Mass - Nozzle Exit: 1.853 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.547 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.190 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Freeform Lift Coefficient Derivative: 6.377/rad
# Tail Lift Coefficient Derivative: -0.915/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: 3.435 m
# Freeform Center of Pressure position: 0.167 m
# Tail Center of Pressure position: 0.129 m
#
# Stability
#
# Center of Mass position (time=0): 1.623 m
# Center of Pressure position (time=0): 1.048 m
# Initial Static Margin (mach=0, time=0): 4.332 c
# Final Static Margin (mach=0, time=burn_out): 5.618 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.575 m
#
#
# Parachute Details
#
# Parachute Main with a cd_s of 6.9115 m2
# Ejection signal trigger: 450 m (AGL)
# Ejection system refresh rate: 105.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 4.0 s
#
#
# Parachute Details
#
# Parachute Drogue with a cd_s of 0.3369 m2
# Ejection signal trigger: At Apogee
# Ejection system refresh rate: 105.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 1.0 s
#
#
# Rocket Draw
# ----------------------------------------
# Mass Plots
# ----------------------------------------
# Aerodynamics Plots
# ----------------------------------------
# Drag Plots
# --------------------
# Stability Plots
# --------------------
# Thrust-to-Weight Plot
# ----------------------------------------

# %% [markdown]
# ### Flight

# %%
from os import name
from rocketpy import CompareFlights

rail_length           = flight_config["rail_length"]
inclination           = flight_config["inclination"]
heading               = flight_config["heading"]
terminate_on_apogee   = flight_config["terminate_on_apogee"]



flight_normal = Flight(
          rocket        = hedy,
          environment   = envNormal,
          rail_length   = rail_length,
          inclination   = inclination,
          heading       = heading,
          terminate_on_apogee = terminate_on_apogee,
          name          = "Normal"
 )
#flight_normal.prints.out_of_rail_conditions()
#flight_normal.prints.apogee_conditions()
#flight_normal.prints.impact_conditions()
#flight_normal.prints.maximum_values()
#flight_normal.plots.trajectory_3d()
#flight_normal.plots.stability_and_control_data()

#flight_normal.plots.all()
flight_normal.prints.all()
#flight_normal.all_info()



flight_forecast = Flight(
          rocket        = hedy,
          environment   = envForecast,
          rail_length   = rail_length,
          inclination   = inclination,
          heading       = heading,
          terminate_on_apogee = terminate_on_apogee,
          name          = "Forecast"
  )
#flight_forecast.prints.out_of_rail_conditions()
#flight_forecast.prints.apogee_conditions()
#flight_forecast.prints.impact_conditions()
#flight_forecast.prints.maximum_values()
#flight_forecast.plots.trajectory_3d()
#flight_forecast.plots.stability_and_control_data()

flight_forecast.prints.all()
#flight_forecast.plots.all()
#flight_forecast.all_info()
# Out:
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 161.00 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.718 | e1: -0.001 | e2: 0.052 | e3: -0.694
# Euler Angles - Spin φ : 45.00° | Nutation θ: -6.00° | Precession ψ: -133.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 4.332 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: 0.00 m/s
# Lateral Surface Wind Speed: 0.00 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 11 m
# Launch Rail Inclination: 84.00°
# Launch Rail Heading: 133.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.512 s
# Rail Departure Velocity: 36.651 m/s
# Rail Departure Stability Margin: 4.367 c
# Rail Departure Angle of Attack: 0.000°
# Rail Departure Thrust-Weight Ratio: 8.386
# Rail Departure Reynolds Number: 3.289e+05
#
#
# Burn out State
#
# Burn out time: 8.143 s
# Altitude at burn out: 2504.922 m (ASL) | 2343.922 m (AGL)
# Rocket speed at burn out: 550.721 m/s
# Freestream velocity at burn out: 550.721 m/s
# Mach Number at burn out: 1.669
# Kinetic energy at burn out: 2.531e+06 J
#
#
# Apogee State
#
# Apogee Time: 38.056 s
# Apogee Altitude: 8059.729 m (ASL) | 7898.729 m (AGL)
# Apogee Freestream Speed: 35.296 m/s
# Apogee X position: 1220.727 m
# Apogee Y position: -1138.346 m
# Apogee latitude: 39.1134532°
# Apogee longitude: -8.0191967°
#
#
# Parachute Events
#
# Parachute: Drogue
# 	Ejection time: 38.057 s
# 	Inflation time: 39.057 s
# 	Freestream speed at inflation: 36.481 m/s
# 	Altitude at inflation: 8054.877 m (ASL) | 7898.729 m (AGL)
# Parachute: Main
# 	Ejection time: 257.962 s
# 	Inflation time: 261.962 s
# 	Freestream speed at inflation: 28.525 m/s
# 	Altitude at inflation: 497.078 m (ASL) | 450.503 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 314.658 s
# X impact: 1432.656 m
# Y impact: -1335.973 m
# Altitude impact: 161.000 m (ASL) | 0.000 m (AGL)
# Latitude: 39.1116776°
# Longitude: -8.0167435°
# Vertical velocity at impact: -6.172 m/s
# Number of parachutes triggered until impact: 2
#
#
# Stability Margin
#
# Initial Stability Margin: 4.332 c at 0.00 s
# Out of Rail Stability Margin: 4.367 c at 0.51 s
# Maximum Stability Margin: 6.335 c at 12.37 s
# Minimum Stability Margin: 4.332 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 550.721 m/s at 8.14 s
# Maximum Mach Number: 1.669 Mach at 8.14 s
# Maximum Reynolds Number: 4.101e+06 at 8.14 s
# Maximum Dynamic Pressure: 1.450e+05 Pa at 8.14 s
# Maximum Acceleration During Motor Burn: 75.338 m/s² at 2.55 s
# Maximum Gs During Motor Burn: 7.682 g at 2.55 s
# Maximum Acceleration After Motor Burn: 12.778 m/s² at 22.27 s
# Maximum Gs After Motor Burn: 1.303 Gs at 22.27 s
# Maximum Stability Margin: 6.335 c at 12.37 s
# Maximum Upper Rail Button Normal Force: 0.000 N
# Maximum Upper Rail Button Shear Force: 0.000 N
# Maximum Lower Rail Button Normal Force: 0.000 N
# Maximum Lower Rail Button Shear Force: 0.000 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 647
# Number of Derivative Functions Evaluation: 161
# Average Function Evaluations per Time Step: 0.249
#
#
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 158.04 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.718 | e1: -0.001 | e2: 0.052 | e3: -0.694
# Euler Angles - Spin φ : 45.00° | Nutation θ: -6.00° | Precession ψ: -133.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 4.332 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: 2.83 m/s
# Lateral Surface Wind Speed: 0.56 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 11 m
# Launch Rail Inclination: 84.00°
# Launch Rail Heading: 133.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.512 s
# Rail Departure Velocity: 36.654 m/s
# Rail Departure Stability Margin: 4.366 c
# Rail Departure Angle of Attack: 4.573°
# Rail Departure Thrust-Weight Ratio: 8.386
# Rail Departure Reynolds Number: 3.128e+05
#
#
# Burn out State
#
# Burn out time: 8.143 s
# Altitude at burn out: 2519.812 m (ASL) | 2361.774 m (AGL)
# Rocket speed at burn out: 551.756 m/s
# Freestream velocity at burn out: 551.713 m/s
# Mach Number at burn out: 1.658
# Kinetic energy at burn out: 2.540e+06 J
#
#
# Apogee State
#
# Apogee Time: 38.367 s
# Apogee Altitude: 8176.706 m (ASL) | 8018.667 m (AGL)
# Apogee Freestream Speed: 20.740 m/s
# Apogee X position: 685.758 m
# Apogee Y position: -676.624 m
# Apogee latitude: 39.1176015°
# Apogee longitude: -8.0253900°
#
#
# Parachute Events
#
# Parachute: Drogue
# 	Ejection time: 38.371 s
# 	Inflation time: 39.371 s
# 	Freestream speed at inflation: 22.783 m/s
# 	Altitude at inflation: 8171.888 m (ASL) | 8018.667 m (AGL)
# Parachute: Main
# 	Ejection time: 260.562 s
# 	Inflation time: 264.562 s
# 	Freestream speed at inflation: 28.771 m/s
# 	Altitude at inflation: 492.825 m (ASL) | 450.149 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 316.489 s
# X impact: 2497.224 m
# Y impact: -210.308 m
# Altitude impact: 158.039 m (ASL) | -0.000 m (AGL)
# Latitude: 39.1217872°
# Longitude: -8.0044144°
# Vertical velocity at impact: -6.247 m/s
# Number of parachutes triggered until impact: 2
#
#
# Stability Margin
#
# Initial Stability Margin: 4.332 c at 0.00 s
# Out of Rail Stability Margin: 4.366 c at 0.51 s
# Maximum Stability Margin: 6.353 c at 12.35 s
# Minimum Stability Margin: 4.332 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 551.756 m/s at 8.14 s
# Maximum Mach Number: 1.658 Mach at 8.14 s
# Maximum Reynolds Number: 4.032e+06 at 8.14 s
# Maximum Dynamic Pressure: 1.447e+05 Pa at 8.14 s
# Maximum Acceleration During Motor Burn: 75.389 m/s² at 2.55 s
# Maximum Gs During Motor Burn: 7.688 g at 2.55 s
# Maximum Acceleration After Motor Burn: 11.694 m/s² at 24.90 s
# Maximum Gs After Motor Burn: 1.192 Gs at 24.90 s
# Maximum Stability Margin: 6.353 c at 12.35 s
# Maximum Upper Rail Button Normal Force: 2.833 N
# Maximum Upper Rail Button Shear Force: 0.552 N
# Maximum Lower Rail Button Normal Force: 3.505 N
# Maximum Lower Rail Button Shear Force: 0.688 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 1102
# Number of Derivative Functions Evaluation: 262
# Average Function Evaluations per Time Step: 0.238
